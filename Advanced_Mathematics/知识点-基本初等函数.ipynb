# %% [markdown]
# # 幂函数

# %% [markdown]
# $ y=x^a $ (a为常数)

# %% [markdown]
# # 指数函数

# %% [markdown]
# $ y=a^x (a > 0, a \neq 1) $

# %% [markdown]
# # 对数函数

# %% [markdown]
# $ y=log_ax (a > 0, a \neq 1) $

# %% [markdown]
# # 三角函数

# %% [markdown]
# 正弦函数 $ y=sinx \quad x \in (-\infty,+\infty) \quad y \in [-1,1] $
# 余弦函数 $ y=cosx \quad x \in (-\infty,+\infty) \quad y \in [-1,1] $
# 正切函数 $ y=tanx \quad (x \neq \frac{\pi}{2} + k\pi, k \in Z) \quad y \in (-\infty,+\infty) $
# 余切函数 $ y=cotx \quad (x \neq \frac{\pi}{2} + k\pi, k \in Z) \quad y \in (-\infty,+\infty) $

# %% [markdown]
# # 反三角函数

# %% [markdown]
# 反正弦函数 $ y=arcsinx \quad x \in [-1,1] \quad y \in [-\frac{\pi}{2}, \frac{\pi}{2}] $
# 反余弦函数 $ y=arccosx \quad x \in [-1,1] \quad y \in [0, \pi] $
# 反正切函数 $ y=arctanx \quad x \in (-\infty,+\infty) \quad y \in (-\frac{\pi}{2}, \frac{\pi}{2}) $
# 反余切函数 $ y=arccotx \quad x \in (-\infty,+\infty) \quad y \in (0, \pi) $
