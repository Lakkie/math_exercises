# %% [markdown]
# 已知$f(x)=\frac{x-1}{x+1}$，求$f(-2), f[f(x)]$.

# %% [markdown]
# # 解：
# $$
# f(-2)=-\frac{-2-1}{-2+1}=3
# $$
# $$
# f[f(x)]=-\frac{\frac{x-1}{x+1}-1}{\frac{x-1}{x+1}+1}=-\frac{1}{x}
# $$
