# %% [markdown]
# 已知$f(\frac{1}{x})=\frac{4}{x}+2x^2+1$，求$f(x), f(x^2+1)$.

# %% [markdown]
# # 解：
# $$
# f(\frac{1}{x})=4\frac{1}{x}+2\frac{1}{(\frac{1}{x})^2}+1
# \Rightarrow
# f(x)=4x+\frac{2}{x^2}+1
# $$
# $$
# f(x^2+1)=4(x^2+1)+\frac{2}{(x^2+1)^2}+1=4x^2+\frac{2}{(x^2+1)^2}+5
# $$
