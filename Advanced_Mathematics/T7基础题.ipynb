# %% [markdown]
# 已知$f(x+\frac{1}{x})=\frac{4x^2}{x^4+1}$，求$f(x)$.

# %% [markdown]
# # 解：
#
# $$
# \begin{align}
# \frac{4x^2}{x^4+1}
# &= \frac{4}{x^2 + \frac{1}{x^2}} \\
# &= \frac{4}{(x + \frac{1}{x})^2 - 2} \\
# \Rightarrow
# f(x) &= \frac{4}{x^2-2}
# \end{align}
# $$
