# %% [markdown]
# 设$f(x)=arccos2x, g(x)=arctanx, h(x)=arccot\frac{x}{2}$, 求$f(\frac{\sqrt{3}}{4}) \cdot g(-1) \cdot h(2) $的值。

# %% [markdown]
# # 解：
#
# $$
# \begin{align}
# f(\frac{\sqrt{3}}{4}) \cdot g(-1) \cdot h(2)
# &= arccos\frac{\sqrt{3}}{2} \cdot arctan(-1) \cdot arccot1 \\
# &= \frac{\pi}{6} \cdot (-\frac{\pi}{4}) \cdot \frac{\pi}{4} \\
# &= -\frac{\pi^3}{96}
# \end{align}
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-1, 1, 100)  # 从-1到1生成100个点
y_arcsin = np.arcsin(x)  # 反正弦函数
y_arccos = np.arccos(x)  # 反余弦函数
y_arctan = np.arctan(x)  # 反正切函数
y_arccot = np.pi / 2 - np.arctan(x) # 反余切函数

plt.figure(figsize=(10, 5))

# 绘制反正弦函数图像
plt.subplot(2, 2, 1)
plt.plot(x, y_arcsin, label='arcsin(x)', color='g')
plt.title('Plot of arcsin(x)')
plt.xlabel('x')
plt.ylabel('arcsin(x)')
plt.grid(True)
plt.legend()
# 绘制反余弦函数图像
plt.subplot(2, 2, 2)
plt.plot(x, y_arccos, label='arccos(x)', color='r')
plt.title('Plot of arccos(x)')
plt.xlabel('x')
plt.ylabel('arccos(x)')
plt.grid(True)
plt.legend()

# 绘制反正切函数图像
plt.subplot(2, 2, 3)
plt.plot(x, y_arctan, label='arctan(x)', color='g')
plt.title('Plot of arctan(x)')
plt.xlabel('x')
plt.ylabel('arctan(x)')
plt.grid(True)
plt.legend()

# 绘制反余切函数图像
plt.subplot(2, 2, 4)
plt.plot(x, y_arccot, label='arccot(x)', color='r')
plt.title('Plot of arccot(x)')
plt.xlabel('x')
plt.ylabel('arccot(x)')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()
